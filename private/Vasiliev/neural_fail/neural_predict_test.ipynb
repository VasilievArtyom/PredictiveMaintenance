# %%
# %matplotlib inline
import math
import numpy as np
from numpy import *
from scipy.optimize import curve_fit
from scipy import signal
from os import path
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Input, Dense, GRU, Embedding, Dense, Activation, Dropout, LSTM
from keras.optimizers import Adam
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
plt.rc('text', usetex=True)

outpath = "../../../plots/temperatures"
inpath = "../../../"

currentfile = "Imitator_2_2400.csv"

# Read from file
strdatatype = np.dtype([('N', np.int_, (2,)), ('Time_Count', np.int_ ), ('Mode', np.int_ ),
                        ('T', np.float_, (10,)), ('S', np.bool_, (10,)), ('System_State', np.bool_ )])
N, Time_Count, Mode, T, S, System_State = np.loadtxt(path.join(inpath, currentfile), 
                                                     unpack=True, delimiter=';', skiprows=1, dtype=strdatatype)

# %%
max_possible_model_temperature = 18
min_possible_model_temperature = 66
def scale_T(_T):
    return ((_T - min_possible_model_temperature) / (max_possible_model_temperature - min_possible_model_temperature)) * 2.0 - 1.0

def unscale_T(_T):
    return ((_T + 1.0) / 2.0) * (max_possible_model_temperature - min_possible_model_temperature) + min_possible_model_temperature

# %%
outputBlockId=0

# %%
predictSteps =1

# %%
sT = scale_T(T)

# %%
print(np.amax(T), np.amin(T))
print(np.amax(sT), np.amin(sT))
# Out:
# 65.14203288058243 18.40911018644466
# 0.9829537422314722 -0.9642513700242681

# %%
delta = np.amin(np.abs(sT[:-2, :] - sT[1:-1, :]))

# %%
delta
# Out:
# 4.885262602116747e-06

# %%
#data augmintation -- 50000 slightly tuned copies of T
agmntCount=10
agmntdT=np.zeros((agmntCount, np.size(sT[:,0]), np.size(sT[0,:])))
agmntdT[0,:,:] = sT
np.random.seed(0)
mu, sigma = 0, delta*500
for i in range(1, agmntCount):
    agmntdT[i] = agmntdT[0] + np.random.normal(mu, sigma, (np.size(sT[:,0]), np.size(sT[0,:])))

# %%
agmntdT.shape
# Out:
# (10, 2401, 10)

# %%
#Keep dataset tail for validate prediction quality
cutFromTail = 150
#In order to have shifted and unshifted series with same shape
t = cutFromTail + predictSteps

# %%
#inData = np.zeros((agmntCount, np.size(sT[:-t,0]), np.size(sT[0,:]) + 1))
#for i in range(0, agmntCount):
#    inData[i,:,0] = Mode[:-t] / np.amax(Mode[:-t])
#    inData[i,:,1:]= agmntdT[i,:-t,:]

inData = np.zeros((agmntCount, np.size(sT[:-t,0]), np.size(sT[0,:])))
for i in range(0, agmntCount):
    inData[i,:,:]= agmntdT[i,:-t,:]

# %%
inData.shape
# Out:
# (10, 2250, 10)

# %%
outData = np.expand_dims(agmntdT[:,predictSteps:-cutFromTail,outputBlockId], axis=2)

# %%
outData.shape
# Out:
# (10, 2250, 1)

# %%
num_data = len(inData[0,:,0])
num_data
# Out:
# 2250

# %%
train_split = 0.80

# %%
num_train = int(train_split * num_data)
num_train
# Out:
# 1800

# %%
num_test = num_data - num_train
num_test
# Out:
# 450

# %%
inData_train = inData[:, 0:num_train, :]
inData_test = inData[:, num_train:, :]
len(inData_train[0,:,0]) + len(inData_test[0,:,0])
# Out:
# 2250

# %%
outData_train = outData[:, 0:num_train, :]
outData_test = outData[:, num_train:, :]
len(outData_train[0,:,0]) + len(outData_test[0,:,0])
# Out:
# 2250

# %%
num_inData_signals = inData.shape[2]
num_inData_signals
# Out:
# 10

# %%
num_outData_signals = outData.shape[2]
num_outData_signals
# Out:
# 1

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16296902850652237494
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3547398144
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 7058433549381128800
# physical_device_desc: "device: 0, name: GeForce GTX 770, pci bus id: 0000:01:00.0, compute capability: 3.0"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 1810169856
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 18170119493053269945
# physical_device_desc: "device: 1, name: GeForce GTX 770, pci bus id: 0000:02:00.0, compute capability: 3.0"
# ]

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """
    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        in_shape = (batch_size, sequence_length, num_inData_signals)
        in_batch = np.zeros(shape=in_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        out_shape = (batch_size, sequence_length, num_outData_signals)
        out_batch = np.zeros(shape=out_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            # This points somewhere into the augmented series range.
            idaugmnt = np.random.randint(agmntCount)
            
            # Copy the sequences of data starting at this index.
            in_batch[i] = inData_train[idaugmnt, idx:idx+sequence_length,:]
            out_batch[i] = outData_train[idaugmnt, idx:idx+sequence_length,:]
        
        yield (in_batch, out_batch)

# %%
batch_size = 512

# %%
#sequence_length=1024
sequence_length=200

# %%
generator = batch_generator(batch_size=batch_size,
                            sequence_length=sequence_length)

# %%
in_batch, out_batch = next(generator)

# %%
print(in_batch.shape)
print(out_batch.shape)
# Out:
# (512, 200, 10)
# (512, 200, 1)

# %%
batch = 0   # First sequence in the batch.
seq = in_batch[batch,predictSteps:predictSteps+50, outputBlockId]
plt.scatter(np.arange(0, len(seq)), seq)

# %%
seq = out_batch[batch, 0:50, 0]
plt.scatter(np.arange(0, len(seq)),seq)

# %%
validation_data = (np.expand_dims(inData_test[0,:,:], axis=0),
                   np.expand_dims(outData_test[0,:,:], axis=0))

# %%
model = Sequential()

# %%
model.add(LSTM(50, return_sequences=True, input_shape=(None, num_inData_signals,)))
model.add(Dense(20, activation = "linear"))
model.add(LSTM(50, return_sequences=True))
model.add(Dense(1, activation = "linear"))

# %%
warmup_steps = 10
import keras.backend as K
def loss_mse_warmup(y_true, y_pred): 
    return K.mean(K.square(y_pred[:, warmup_steps:, :]-y_true[:, warmup_steps:, :]))

# %%
#model.compile(Adam(learning_rate=1e-4), loss='mean_absolute_error')
model.compile(Adam(learning_rate=5e-5), loss=loss_mse_warmup)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, None, 50)          12200
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 20)          1020
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 50)          14200
# _________________________________________________________________
# dense_2 (Dense)              (None, None, 1)           51
# =================================================================
# Total params: 27,471
# Trainable params: 27,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = str(outputBlockId)+'_multistep_test_bestfit_on_20_steps.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %%
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=20, verbose=1)

# %%
callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-10,
                                       patience=0,
                                       verbose=1)

# %%
callbacks = [callback_early_stopping,
            callback_checkpoint,
            callback_reduce_lr]

# %%
#try:
#    model.load_weights(str(outputBlockId)+'_multistep_test.keras')
#except Exception as error:
#    print("Error trying to load checkpoint.")
#    print(error)
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)
# Out:
# Error trying to load checkpoint.
# Layer #1 (named "dense_1" in the current model) was found to correspond to layer lstm_5 in the save file. However the new layer dense_1 expects 2 weights, but the saved weights have 3 elements.

# %%
# %%time
model.fit_generator(generator=generator,
                    epochs=1000000,
                    steps_per_epoch=50,
                    validation_data=validation_data,
                    callbacks=callbacks)
# Out:
# Epoch 1/1000000
# 50/50 [==============================] - 14s 289ms/step - loss: 0.1225 - val_loss: 0.0963
#
# Epoch 00001: val_loss improved from inf to 0.09633, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 2/1000000
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0999 - val_loss: 0.0832
#
# Epoch 00002: val_loss improved from 0.09633 to 0.08319, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 3/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0829 - val_loss: 0.0694
#
# Epoch 00003: val_loss improved from 0.08319 to 0.06936, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 4/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0681 - val_loss: 0.0578
#
# Epoch 00004: val_loss improved from 0.06936 to 0.05779, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 5/1000000
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0565 - val_loss: 0.0498
#
# Epoch 00005: val_loss improved from 0.05779 to 0.04984, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 6/1000000
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0480 - val_loss: 0.0444
#
# Epoch 00006: val_loss improved from 0.04984 to 0.04439, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 7/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0421 - val_loss: 0.0409
#
# Epoch 00007: val_loss improved from 0.04439 to 0.04087, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 8/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0375 - val_loss: 0.0387
#
# Epoch 00008: val_loss improved from 0.04087 to 0.03870, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 9/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0338 - val_loss: 0.0369
#
# Epoch 00009: val_loss improved from 0.03870 to 0.03687, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 10/1000000
# 50/50 [==============================] - 14s 279ms/step - loss: 0.0306 - val_loss: 0.0353
#
# Epoch 00010: val_loss improved from 0.03687 to 0.03531, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 11/1000000
# 50/50 [==============================] - 14s 286ms/step - loss: 0.0280 - val_loss: 0.0337
#
# Epoch 00011: val_loss improved from 0.03531 to 0.03372, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 12/1000000
# 50/50 [==============================] - 14s 280ms/step - loss: 0.0256 - val_loss: 0.0319
#
# Epoch 00012: val_loss improved from 0.03372 to 0.03190, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 13/1000000
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0236 - val_loss: 0.0297
#
# Epoch 00013: val_loss improved from 0.03190 to 0.02969, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 14/1000000
# 50/50 [==============================] - 13s 270ms/step - loss: 0.0220 - val_loss: 0.0277
#
# Epoch 00014: val_loss improved from 0.02969 to 0.02768, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 15/1000000
# 50/50 [==============================] - 14s 271ms/step - loss: 0.0205 - val_loss: 0.0256
#
# Epoch 00015: val_loss improved from 0.02768 to 0.02563, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 16/1000000
# 50/50 [==============================] - 14s 282ms/step - loss: 0.0192 - val_loss: 0.0243
#
# Epoch 00016: val_loss improved from 0.02563 to 0.02428, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 17/1000000
# 50/50 [==============================] - 14s 283ms/step - loss: 0.0180 - val_loss: 0.0231
#
# Epoch 00017: val_loss improved from 0.02428 to 0.02305, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 18/1000000
# 50/50 [==============================] - 14s 283ms/step - loss: 0.0171 - val_loss: 0.0221
#
# Epoch 00018: val_loss improved from 0.02305 to 0.02207, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 19/1000000
# 50/50 [==============================] - 14s 276ms/step - loss: 0.0161 - val_loss: 0.0213
#
# Epoch 00019: val_loss improved from 0.02207 to 0.02132, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 20/1000000
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0153 - val_loss: 0.0206
#
# Epoch 00020: val_loss improved from 0.02132 to 0.02061, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 21/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0145 - val_loss: 0.0201
#
# Epoch 00021: val_loss improved from 0.02061 to 0.02014, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 22/1000000
# 50/50 [==============================] - 14s 276ms/step - loss: 0.0138 - val_loss: 0.0197
#
# Epoch 00022: val_loss improved from 0.02014 to 0.01972, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 23/1000000
# 50/50 [==============================] - 14s 276ms/step - loss: 0.0131 - val_loss: 0.0195
#
# Epoch 00023: val_loss improved from 0.01972 to 0.01951, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 24/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0125 - val_loss: 0.0194
#
# Epoch 00024: val_loss improved from 0.01951 to 0.01942, saving model to 0_multistep_test_bestfit_on_20_steps.keras
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# Epoch 25/1000000
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0122 - val_loss: 0.0194
#
# Epoch 00025: val_loss improved from 0.01942 to 0.01936, saving model to 0_multistep_test_bestfit_on_20_steps.keras
# Epoch 26/1000000
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00026: val_loss improved from 0.01936 to 0.01932, saving model to 0_multistep_test_bestfit_on_20_steps.keras
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-07.
# Epoch 27/1000000
# 50/50 [==============================] - 13s 267ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00027: val_loss did not improve from 0.01932
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.999999987376214e-08.
# Epoch 28/1000000
# 50/50 [==============================] - 14s 289ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00028: val_loss did not improve from 0.01932
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.000000058430488e-09.
# Epoch 29/1000000
# 50/50 [==============================] - 13s 270ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00029: val_loss did not improve from 0.01932
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.999999969612646e-10.
# Epoch 30/1000000
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00030: val_loss did not improve from 0.01932
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 31/1000000
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00031: val_loss did not improve from 0.01932
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 32/1000000
# 50/50 [==============================] - 13s 265ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00032: val_loss did not improve from 0.01932
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 33/1000000
# 50/50 [==============================] - 13s 265ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00033: val_loss did not improve from 0.01932
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 34/1000000
# 50/50 [==============================] - 13s 265ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00034: val_loss did not improve from 0.01932
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 35/1000000
# 50/50 [==============================] - 14s 277ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00035: val_loss did not improve from 0.01932
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 36/1000000
# 50/50 [==============================] - 15s 299ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00036: val_loss did not improve from 0.01932
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 37/1000000
# 50/50 [==============================] - 14s 283ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00037: val_loss did not improve from 0.01932
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 38/1000000
# 50/50 [==============================] - 14s 279ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00038: val_loss did not improve from 0.01932
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 39/1000000
# 50/50 [==============================] - 14s 272ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00039: val_loss did not improve from 0.01932
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 40/1000000
# 50/50 [==============================] - 14s 270ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00040: val_loss did not improve from 0.01932
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 41/1000000
# 50/50 [==============================] - 13s 270ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00041: val_loss did not improve from 0.01932
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 42/1000000
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00042: val_loss did not improve from 0.01932
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 43/1000000
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00043: val_loss did not improve from 0.01932
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 44/1000000
# 50/50 [==============================] - 14s 271ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00044: val_loss did not improve from 0.01932
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 45/1000000
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00045: val_loss did not improve from 0.01932
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 46/1000000
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0121 - val_loss: 0.0193
#
# Epoch 00046: val_loss did not improve from 0.01932
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-10.
# Epoch 00046: early stopping
# CPU times: user 15min 21s, sys: 48.9 s, total: 16min 10s
# Wall time: 10min 28s

# %%
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %%
result = model.evaluate(x=np.expand_dims(inData_test[0], axis=0),
                        y=np.expand_dims(outData_test[0], axis=0))
# Out:
# 1/1 [==============================] - 0s 87ms/step

# %%
print("loss (test-set):", result)
# Out:
# loss (test-set): 0.01932322047650814

# %%
def plot_comparison(start_idx, length=100, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = inData_train[0]
        y_true = outData_train[0]
    else:
        # Use test-data.
        x = inData_test[0]
        y_true = outData_test[0]
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    print(shape(x))
    print(shape(y_pred))
        
    # Get the output-signal predicted by the model.
    signal_pred = y_pred
        
    # Get the true output-signal from the data-set.
    signal_true = y_true
    
    # Make the plotting-canvas bigger.
    plt.figure(figsize=(15,5))
        
    # Plot and compare the two signals.
    plt.plot(signal_true, label='true')
    plt.scatter(np.arange(0, len(signal_pred[0])), signal_pred[0,:,:], label='pred', color='r')

        
    # Plot labels etc.
    plt.legend()
    plt.show()

# %%
plot_comparison(start_idx=0, length=400, train=False)
# Out:
# (1, 400, 10)
# (1, 400, 1)

# %%
sequence_length_for_predict = sequence_length

def predStepForAllBlc(_in):
    _out = np.zeros((1, sequence_length_for_predict, 10))
    for blk_id in range(0, 10):
            path_to_current_model = str(blk_id)+'_multistep_test_bestfit_on_10_steps.keras'
            try:
                model.load_weights(path_to_current_model)
            except Exception as error:
                print("Error trying to load model for block "+str(blk_id+1))
                print(error)
            _out[0, :, blk_id] = model.predict(_in)[0,:,0]
    return _out[0, -predictSteps:, :]
            
def performOfSamplePrediction(outOfSampleCount):    
    prediction = np.zeros(((outOfSampleCount // predictSteps) * (predictSteps + 1), 10))
    
    predictBase = np.zeros((1, sequence_length_for_predict, num_inData_signals))
    onStepPredict = np.zeros((1, sequence_length_for_predict, 10))
   
    predictBase[0,:,:] = sT[-(sequence_length_for_predict + cutFromTail): -cutFromTail,:]
    
    prediction[0:predictSteps,:] = predStepForAllBlc(predictBase)
    for step in range(predictSteps,outOfSampleCount,predictSteps):
            predictBase[0,:-predictSteps,:] = predictBase[0,predictSteps:,:]
            predictBase[0,-predictSteps:,:] = prediction[(step - predictSteps):step,:]
            prediction[step:step+predictSteps,:] = predStepForAllBlc(predictBase)
    return prediction

# %%
pred = performOfSamplePrediction(predictSteps + cutFromTail)
# Out:
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# ...
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 1
# You are trying to load a weight file containing 3 layers into a model with 4 layers.
# Error trying to load model for block 2
# Unable to open file (unable to open file: name = '1_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 3
# Unable to open file (unable to open file: name = '2_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 4
# Unable to open file (unable to open file: name = '3_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 5
# Unable to open file (unable to open file: name = '4_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 6
# Unable to open file (unable to open file: name = '5_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 7
# Unable to open file (unable to open file: name = '6_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 8
# Unable to open file (unable to open file: name = '7_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 9
# Unable to open file (unable to open file: name = '8_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Error trying to load model for block 10
# Unable to open file (unable to open file: name = '9_multistep_test_bestfit_on_10_steps.keras', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
for _id in range (0, 10):
    plt.figure(figsize=(15,2))
    plt.plot(pred[:,_id])
    plt.plot(sT[-(predictSteps + cutFromTail):, _id], color='gray')
    plt.ylabel("Block"+str(_id+1))
